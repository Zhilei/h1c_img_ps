# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from matplotlib import colors
from direct_optimal_mapping import dom_pspec
from direct_optimal_mapping import image_cube_compilation
from copy import deepcopy
import pickle

# %matplotlib notebook

# %% [markdown]
# # Map Data Acquisition

# %% [markdown]
# The map files were generated by mapping scripts stored in this repository https://github.com/Zhilei/dom_radec <br>
# Specifically, the script generated the files below is https://github.com/Zhilei/dom_radec/blob/main/h1c_idr22_mapping_radec_grid_validation.py

# %%
field = "field1"
band = 'band2'
split = 'even'
map_files1_pol1 = sorted(glob('/nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/%s/%s/%s/h1c_idr22_*pol-5*.p'%(field, band, split)))
map_files1_pol2 = sorted(glob('/nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/%s/%s/%s/h1c_idr22_*pol-6*.p'%(field, band, split)))

print(len(map_files1_pol1), '+', len(map_files1_pol1), 'files found.')
print('First file:\n', map_files1_pol1[0], '\n', map_files1_pol2[0])
print('Last file:\n', map_files1_pol1[-1], '\n', map_files1_pol2[-1])

split = 'odd'
map_files2_pol1 = sorted(glob('/nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/%s/%s/%s/h1c_idr22_*pol-5*.p'%(field, band, split)))
map_files2_pol2 = sorted(glob('/nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/%s/%s/%s/h1c_idr22_*pol-6*.p'%(field, band, split)))
print(len(map_files2_pol1), '+', len(map_files2_pol1), 'files found.')
print('First file:\n', map_files2_pol1[0], '\n', map_files2_pol1[0])
print('Last file:\n', map_files2_pol1[-1], '\n', map_files2_pol2[-1])
# Out:
# 180 + 180 files found.
# First file:
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/even/h1c_idr22_field1_even_150.29MHz_pol-5_radec_grid_RA45Dec16.p
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/even/h1c_idr22_field1_even_150.29MHz_pol-6_radec_grid_RA45Dec16.p
# Last file:
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/even/h1c_idr22_field1_even_167.77MHz_pol-5_radec_grid_RA45Dec16.p
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/even/h1c_idr22_field1_even_167.77MHz_pol-6_radec_grid_RA45Dec16.p
# 180 + 180 files found.
# First file:
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/odd/h1c_idr22_field1_odd_150.29MHz_pol-5_radec_grid_RA45Dec16.p
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/odd/h1c_idr22_field1_odd_150.29MHz_pol-5_radec_grid_RA45Dec16.p
# Last file:
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/odd/h1c_idr22_field1_odd_167.77MHz_pol-5_radec_grid_RA45Dec16.p
#  /nfs/ger/home/zhileixu/data/optimal_mapping/h1c_idr22/radec_grid/field1/band2/odd/h1c_idr22_field1_odd_167.77MHz_pol-6_radec_grid_RA45Dec16.p

# %% [markdown]
# # Overall Skeleton Procedure

# %% [markdown]
# # Set up image cube
# img_cube1 = image_cube_compilation.ImgCube(map_files1_pol1,
#                                            map_files1_pol2,
#                                            )
# img_cube2 = image_cube_compilation.ImgCube(map_files2_pol1,
#                                            map_files2_pol2,
#                                            )
# img_dic1 = img_cube1.image_cube_calc()
# img_dic2 = img_cube2.image_cube_calc()
# p_dic = img_cube1.p_mat_calc()
# # Initiate power spectrum calculation
# ps_calc = dom_pspec.PS_Calc(img_dic1, img_dic1, par_taper='bh', per_taper='bh')
# ps_calc.set_cosmo_grid()
#
# # Power spectrum calculation and normalization
# ps_calc.calc_fft(volume='original')
# ps_calc.set_k_space(binning='lin')
# ps_calc.norm_calc(p_dic, norm_data=True)
#
# # Binning to 2D and 1D power spectra
# ps_calc.set_k_space(binning='lin')
# ps_calc.calc_ps1d(avoid_fg=False, max_kperp=0.04)

# %% [markdown]
# # Overall Procedure with Illustrations

# %%
img_cube1 = image_cube_compilation.ImgCube(map_files1_pol1,
                                           map_files1_pol2,
                                           )
img_dic1 = img_cube1.image_cube_calc()

img_cube2 = image_cube_compilation.ImgCube(map_files2_pol1,
                                           map_files2_pol2,
                                           )
img_dic2 = img_cube2.image_cube_calc()

print('Image Cube 1 dimension:', img_dic1['data_cube_I'].shape)
print('Image Cube 2 dimension:', img_dic2['data_cube_I'].shape)
# Out:
# Image Cube 1 dimension: (180, 90, 32)
# Image Cube 2 dimension: (180, 90, 32)

# %%
fig, ax = plt.subplots(ncols=3, figsize=(9, 3))

i_t = 0
cax = ax[0].pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], img_dic1['data_cube_I'][i_t].T)
ax[0].set_title('%.2fMHz'%img_dic1['freq_mhz'][i_t])
ax[0].set_xlabel('RA (deg)')
ax[0].set_ylabel('Dec (deg)')
# ax[0].invert_xaxis()
ax[0].set_aspect('equal')
cbar = plt.colorbar(cax, ax=ax[0], orientation='horizontal')
cbar.set_label('mK')
ax[0].invert_xaxis()

i_t = 89
cax = ax[1].pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], img_dic1['data_cube_I'][i_t].T)
ax[1].set_title('%.2fMHz'%img_dic1['freq_mhz'][i_t])
ax[1].set_xlabel('RA (deg)')
ax[1].set_ylabel('Dec (deg)')
# ax[1].invert_xaxis()
ax[1].set_aspect('equal')
cbar = plt.colorbar(cax, ax=ax[1], orientation='horizontal')
cbar.set_label('mK')
ax[1].invert_xaxis()

i_t = -1
cax = ax[2].pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], img_dic1['data_cube_I'][i_t].T)
ax[2].set_title('%.2fMHz'%img_dic1['freq_mhz'][i_t])
ax[2].set_xlabel('RA (deg)')
ax[2].set_ylabel('Dec (deg)')
# ax[2].invert_xaxis()
ax[2].set_aspect('equal')
cbar = plt.colorbar(cax, ax=ax[2], orientation='horizontal')
cbar.set_label('mK')
ax[2].invert_xaxis()

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
ps_calc = dom_pspec.PS_Calc(img_dic1, img_dic2, par_taper='bh', per_taper='bh')

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(8, 6))
ax = ax.flatten()
ifreq = 0
cb_range = 30
ax_t = ax[0]
cax = ax_t.pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], 
                      ps_calc.taper_3d[ifreq].T,
                      #vmin=-cb_range, vmax=cb_range, 
                      cmap='coolwarm')
ax_t.set_title('Tapering Function')
ax_t.set_xlabel('RA (deg)')
ax_t.set_ylabel('Dec (deg)')
cbar = plt.colorbar(cax, ax=ax_t, orientation='horizontal', pad=0.23)
ax_t.invert_xaxis()
ax_t.set_aspect('equal')

ax_t = ax[1]
cax = ax_t.pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], 
                      ps_calc.taper_3d[ifreq+59].T,
                      #vmin=-cb_range, vmax=cb_range, 
                      cmap='coolwarm')
ax_t.set_title('Tapering Function')
ax_t.set_xlabel('RA (deg)')
cbar = plt.colorbar(cax, ax=ax_t, orientation='horizontal', pad=0.23)
ax_t.invert_xaxis()
ax_t.set_aspect('equal')

ax_t = ax[2]
ax_t.plot(img_dic1['freq_mhz'], ps_calc.taper_3d[:, 0, 0])
ax_t.set_xlabel('Frequency (MHz)')
ax_t.set_ylabel('Tapering')

ax_t = ax[3]
ax_t.plot(img_dic1['freq_mhz'], ps_calc.taper_3d[:, 15, 7])
ax_t.set_xlabel('Frequency (MHz)')
ax_t.set_ylabel('Tapering')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig, ax = plt.subplots(ncols=2, figsize=(6, 3))
ifreq = 91
cb_range = 200
cb_zoom_factor = 1

print(img_dic1['freq_mhz'][ifreq], 'MHz')

ax_t = ax[0]
cax = ax_t.pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], img_dic1['data_cube_I'][ifreq].T,
                      vmin=-cb_range, vmax=cb_range, 
                      cmap='coolwarm')
ax_t.set_title(r'Original Map')
ax_t.set_xlabel('RA (deg)')
ax_t.set_ylabel('Dec (deg)')
# cbar = plt.colorbar(cax, ax=ax_t, orientation='horizontal', pad=0.23)
# cbar.set_label('mK')
ax_t.set_aspect('equal')
ax_t.invert_xaxis()


map_tp = img_dic1['data_cube_I'][ifreq] * ps_calc.taper_3d[ifreq]
ax_t = ax[1]
cax = ax_t.pcolormesh(img_dic1['px_dic']['ra_deg'][:, 0], img_dic1['px_dic']['dec_deg'][0], map_tp.T,
                      vmin=-cb_range/cb_zoom_factor, vmax=cb_range/cb_zoom_factor, 
                      cmap='coolwarm')
ax_t.set_title(r'Tapered Map')
ax_t.set_xlabel('RA (deg)')
# ax_t.set_ylabel('Dec (deg)')
ax_t.set_aspect('equal')
ax_t.invert_xaxis()

fig.subplots_adjust(hspace=0, top=0.97, left=0.0, bottom=0.4)
cbar_ax = fig.add_axes([0.30, 0.15, 0.4, 0.02])
cbar = fig.colorbar(cax, cax=cbar_ax, orientation='horizontal')
# cbar = plt.colorbar(cax, ax=cbar_ax, orientation='horizontal', pad=0.23)
cbar.set_label('mK')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">
# 159.1796875 MHz
# /tmp/ipykernel_41094/3190064089.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
ps_calc.set_cosmo_grid()

print('Frequency (MHz) range:', np.ptp(ps_calc.freq_mhz))
print('LOS Distance (Mpc/h):', ps_calc.dist_cm_h[0], '+', np.ptp(ps_calc.dist_cm_h))
print('Distances changes (fractional) by:', (ps_calc.dist_cm_h[0]-ps_calc.dist_cm_h[-1])/np.mean(ps_calc.dist_cm_h))
dist_intvl = -np.diff(ps_calc.dist_cm_h)
print('LOS Distance Interval (Mpc/h):', dist_intvl[0], '+', np.ptp(dist_intvl))
print('Distance Interval changes (fractional) by:', (dist_intvl[-1]-dist_intvl[0])/np.mean(dist_intvl))

print('Perpendicular to LOS distances range:', np.radians(16)*np.mean(ps_calc.dist_cm_h))
print('Perpendicular to LOS distances resol:', np.radians(0.5)*np.mean(ps_calc.dist_cm_h))

print('Voxel size (avg):', ps_calc.res_x_mpch * ps_calc.res_y_mpch * ps_calc.res_z_mpch, '(Mpc/h)^3')
# Out:
# Frequency (MHz) range: 17.48046875
# LOS Distance (Mpc/h): 6449.289546640984 Mpc / littleh + 205.43773559168676 Mpc / littleh
# Distances changes (fractional) by: 0.03237469388840658
# LOS Distance Interval (Mpc/h): 1.180191052743794 Mpc / littleh + 0.06330119800622924 Mpc / littleh
# Distance Interval changes (fractional) by: -0.055154981194085705
# Perpendicular to LOS distances range: 1772.0333820116066 Mpc / littleh
# Perpendicular to LOS distances resol: 55.376043187862706 Mpc / littleh
# Voxel size (avg): 3519.419449790567 (Mpc/h)^3

# %%
shape = np.array((ps_calc.nz, ps_calc.nx, ps_calc.ny))
p_dic = img_cube1.p_mat_calc()

# %%
fig = plt.figure(figsize=(8, 3))

ax_t = fig.add_axes([0.17, 0.33, 0.3, 0.5])
ifreq = 0
ipx = 1456
cb_pad = 0.2
vmin = -1e-3
vmax = 1e-3
cax = ax_t.pcolormesh(p_dic['px_dic']['ra_deg'][:, 0], p_dic['px_dic']['dec_deg'][0],  p_dic['p_mat_I'][ifreq, ipx, :].reshape(shape[1:]).T, 
               cmap='seismic', 
                      vmin=vmin, vmax=vmax
                     )
ax_t.set_xlabel('RA (deg)')
ax_t.set_ylabel('Dec (deg)')
ax_t.set_aspect('equal')
ax_t.set_title('%.2fMHz'%img_dic1['freq_mhz'][ifreq])
ax_t.invert_xaxis()

ax_t = fig.add_axes([0.53, 0.33, 0.3, 0.5])
ifreq = -1
cax = ax_t.pcolormesh(p_dic['px_dic']['ra_deg'][:, 0], p_dic['px_dic']['dec_deg'][0],  p_dic['p_mat_I'][ifreq, ipx, :].reshape(shape[1:]).T, 
               cmap='seismic', 
                      vmin=vmin, vmax=vmax
                     )

ax_t.set_xlabel('RA (deg)')
ax_t.set_aspect('equal')
ax_t.set_title('%.2fMHz'%img_dic1['freq_mhz'][ifreq])
ax_t.invert_xaxis()
ax_t.set_yticklabels([])

ax_t = fig.add_axes([0.3, 0.15, 0.4, 0.02])
fig.colorbar(cax, cax=ax_t, orientation='horizontal')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
# /tmp/ipykernel_41094/653546766.py:35: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
ps_calc.calc_fft(volume='original')
ps_calc.set_k_space(binning='lin')
ps_calc.norm_calc(p_dic, norm_data=True)
ps_calc.set_k_space(binning='lin')
ps_calc.calc_ps1d(avoid_fg=False, max_kperp=0.04)

# %%
x_lim = [5e-3, 4e-2]
y_lim = [1.5e-2, 2.5]
cmap_min = 1e6
cmap_max = 1e14

from astropy.cosmology import WMAP9 as cosmo
import hera_pspec.conversions as conversions
cos_conversion = conversions.Cosmo_Conversions(Om_L=cosmo.Ode0, Om_b=cosmo.Ob0, Om_c=cosmo.Odm0, H0=cosmo.H0.value)
z_avg = np.mean(ps_calc.redshift)

def bl2kperp(x, z=z_avg):
    return cos_conversion.bl_to_kperp(z) * x
def kperp2bl(x, z=z_avg):
    return x/cos_conversion.bl_to_kperp(z)

def tau2kpara(x, z=z_avg):
    return cos_conversion.tau_to_kpara(z_avg) * x*1e-9
def kpara2tau(x, z=z_avg):
    return x*1e9/cos_conversion.tau_to_kpara(z_avg)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 4))

ax_t = ax[0]

cax = ax_t.pcolormesh(ps_calc.k_perp, ps_calc.k_para, ps_calc.ps2d.T, 
                      norm=colors.LogNorm(vmax=cmap_max, vmin=cmap_min), cmap='nipy_spectral')
ax_t.set_xlabel(r'$k_\bot$ $[h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_ylabel(r'$k_\parallel$ $[h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_title('Normalized 2D Power Spectrum')
ax_t.set_xscale('log')
ax_t.set_xlim(x_lim)
ax_t.set_yscale('log')
ax_t.set_ylim(y_lim)
cbar = plt.colorbar(cax, ax=ax_t, orientation='vertical', pad=0.2)
cbar.set_label(r'$P(k_\parallel, k_\bot)\ [\mathrm{mK}^2 \mathrm{h}^{-3} \mathrm{Mpc}^3]$')
ax_t.plot(ps_calc.k_perp_edge, ps_calc.slope*ps_calc.k_perp_edge, c='grey', ls='--')
ax_t.plot(ps_calc.k_perp_edge, ps_calc.slope*ps_calc.k_perp_edge + ps_calc.y_intercept, c='k')

secxax = ax_t.secondary_xaxis('top', functions=(kperp2bl, bl2kperp))
secxax.set_xlabel('Baseline (m)', labelpad=0)
secyax = ax_t.secondary_yaxis('right', functions=(kpara2tau, tau2kpara))
secyax.set_ylabel('Delay (ns)')

ax_t.set_xticklabels([], minor=True)
secxax.set_xticklabels([], minor=True)

ax_t = ax[1]
ax_t.errorbar(ps_calc.kr, ps_calc.ps1d, 
             yerr=ps_calc.ps1d_std/np.sqrt(ps_calc.ps1d_nsample), 
#              yerr=ps_calc.ps1d_std, 
             fmt='.-', label=r'Data')
ax_t.errorbar(ps_calc.kr, -ps_calc.ps1d, 
             yerr=ps_calc.ps1d_std/np.sqrt(ps_calc.ps1d_nsample), 
#              yerr=ps_calc.ps1d_std, 
             fmt='.', label=r'Data (Neg. Flipped)')
ax_t.set_yscale('log')
# plt.xscale('log')
ax_t.set_xlabel('$k\ [h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_ylabel(r'$P(k)\ [\mathrm{mK}^2 \mathrm{h}^{-3} \mathrm{Mpc}^3]$')
ax_t.set_title('1D Power Spectrum (Field1, %s)'%band)
ax_t.grid()

ax_t.legend(loc='lower left')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 4))

ax_t = ax[0]

cax = ax_t.pcolormesh(ps_calc.k_perp, ps_calc.k_para, ps_calc.ps2d.T, 
                      norm=colors.LogNorm(vmax=cmap_max, vmin=cmap_min), cmap='nipy_spectral')
ax_t.set_xlabel(r'$k_\bot$ $[h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_ylabel(r'$k_\parallel$ $[h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_title('Normalized 2D Power Spectrum')
ax_t.set_xscale('log')
ax_t.set_xlim(x_lim)
ax_t.set_yscale('log')
ax_t.set_ylim(y_lim)
cbar = plt.colorbar(cax, ax=ax_t, orientation='vertical', pad=0.2)
cbar.set_label(r'$P(k_\parallel, k_\bot)\ [\mathrm{mK}^2 \mathrm{h}^{-3} \mathrm{Mpc}^3]$')
ax_t.plot(ps_calc.k_perp_edge, ps_calc.slope*ps_calc.k_perp_edge, c='grey', ls='--')
ax_t.plot(ps_calc.k_perp_edge, ps_calc.slope*ps_calc.k_perp_edge + ps_calc.y_intercept, c='k')

secxax = ax_t.secondary_xaxis('top', functions=(kperp2bl, bl2kperp))
secxax.set_xlabel('Baseline (m)', labelpad=0)
secyax = ax_t.secondary_yaxis('right', functions=(kpara2tau, tau2kpara))
secyax.set_ylabel('Delay (ns)')

ax_t.set_xticklabels([], minor=True)
secxax.set_xticklabels([], minor=True)

ax_t = ax[1]
peak = ps_calc.ps1d.max()
ax_t.errorbar(ps_calc.kr, ps_calc.ps1d/peak, 
             yerr=ps_calc.ps1d_std/np.sqrt(ps_calc.ps1d_nsample)/peak, 
#              yerr=ps_calc.ps1d_std, 
             fmt='.-', label=r'Data')
ax_t.errorbar(ps_calc.kr, -ps_calc.ps1d/peak, 
             yerr=ps_calc.ps1d_std/np.sqrt(ps_calc.ps1d_nsample)/peak, 
#              yerr=ps_calc.ps1d_std, 
             fmt='.', label=r'Data (Neg. Flipped)')
ax_t.set_yscale('log')
# plt.xscale('log')
ax_t.set_xlabel('$k\ [h\, \mathrm{Mpc}^{-1}]$')
ax_t.set_ylabel(r'$P(k)\ [\mathrm{mK}^2 \mathrm{h}^{-3} \mathrm{Mpc}^3]$')
ax_t.set_title('1D Power Spectrum\n(Field1, %s, Peak Norm.)'%band)
ax_t.grid()

ax_t.legend()

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# img_2dps = {'kperp': ps_calc.k_perp,
#             'kperp_edge':ps_calc.k_perp_edge,
#             'kpara': ps_calc.k_para,
#             '2dps': ps_calc.ps2d.T,
#             'slope': ps_calc.slope,
#             'y_intercept': ps_calc.y_intercept,}
# img_1dps = {'k': ps_calc.kr,
#             '1dps': ps_calc.ps1d,}
# with open('data/img_2dps_xyz-bh_h1cidr22_f1b2.p', 'wb') as f_t:
#     pickle.dump(img_2dps, f_t)
# with open('data/img_1dps_xyz-bh_h1cidr22_f1b2.p', 'wb') as f_t:
#     pickle.dump(img_1dps, f_t)
